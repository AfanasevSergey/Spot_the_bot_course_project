# %% [markdown]
# https://www.notion.so/yarolika00/Instructions-for-Spot-the-bot-b2aad50308d64ca388108a9f76976ccf

# %%
import requests, bs4, os, errno, zipfile, glob
from urllib.request import urlretrieve
import pandas as pd
import nltk
import codecs

# %% [markdown]
# # Spanish

# %%
if not os.path.exists('books_es/'):
    try:
        os.makedirs('books_es/')
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise

# %%
urls_to_books = []

if not os.path.exists('urls_to_books_es.txt'):
    page_w_books_url = 'http://www.gutenberg.org/robot/harvest?filetypes%5B%5D=txt&langs%5B%5D=es&#39;'
    
    while 1 == 1:
        is_last_page = False
        print('Reading page: ' + page_w_books_url)
        page_w_books = requests.get(page_w_books_url, timeout=20.0)
        
        if page_w_books:
            page_w_books = bs4.BeautifulSoup(page_w_books.text, "lxml")
            urls = [el.get('href') for el in page_w_books.select('body > p > a')]
            url_to_next_page = page_w_books.find_all('a', string='Next Page')
            
            if len(urls) > 0:
                urls_to_books.append(urls)

                if url_to_next_page[0]:
                    page_w_books_url = "http://www.gutenberg.org/robot/" + url_to_next_page[0].get('href')
            else:
                is_last_page = True

        if is_last_page:
            break
# Out:
# Reading page: http://www.gutenberg.org/robot/harvest?filetypes%5B%5D=txt&langs%5B%5D=es&#39;
# Reading page: http://www.gutenberg.org/robot/harvest?offset=181196&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=784057&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=1638865&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=3328551&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=4802445&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=18648124&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=29172548&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=41814221&filetypes[]=txt&langs[]=es
# Reading page: http://www.gutenberg.org/robot/harvest?offset=41903620&filetypes[]=txt&langs[]=es

# %%
urls_to_books = [item for sublist in urls_to_books for item in sublist]
# Backing up the list of URLs

with open('urls_to_books_es.txt', 'w') as output:
    for u in urls_to_books:
        output.write('%s\n' % u)

# %%
print("Books count: ", len(urls_to_books))
# Out:
# Books count:  811

# %%
if os.path.exists('urls_to_books_es.txt') and len(urls_to_books) == 0:
    with open('urls_to_books_es.txt', 'r') as f:
        urls_to_books = f.read().splitlines()

# %%
#collect books
url_num = 0

for url in urls_to_books[url_num:]:
    dst = 'books_es/' + url.split('/')[-1].split('.')[0].split('-')[0]
    
    if url.find('http://') > -1:
    
        with open('logfile.log', 'w') as f:
            f.write('Unzipping file #' + str(url_num) + ' ' + dst + '.zip' + '\n')

        if len(glob.glob(dst + '*')) == 0:
            urlretrieve(url, dst + '.zip')

            with zipfile.ZipFile(dst + '.zip', "r") as zip_ref:
                try:
                    zip_ref.extractall("books_es/")
                    print(str(url_num) + ' ' + dst + '.zip ' + 'unzipped successfully!')
                    book_dict[url_num] = dst + '.zip'
                    
                except (URLError, HTTPError, ContentTooShortError) as e:
                    print(str(url_num) + ' Error occurs with file:', dst, str(e))

            os.remove(dst + '.zip')

        url_num += 1
# Out:
# 0 books_es/10293.zip unzipped successfully!
# 2 books_es/10506.zip unzipped successfully!
# 4 books_es/10814.zip unzipped successfully!
# 6 books_es/10821.zip unzipped successfully!
# 8 books_es/10822.zip unzipped successfully!
# 10 books_es/10825.zip unzipped successfully!
# 11 books_es/10909.zip unzipped successfully!
# 13 books_es/11047.zip unzipped successfully!
# 15 books_es/11070.zip unzipped successfully!
# 17 books_es/11071.zip unzipped successfully!
# 19 books_es/11081.zip unzipped successfully!
# 21 books_es/11302.zip unzipped successfully!
# 22 books_es/11529.zip unzipped successfully!
# 24 books_es/11598.zip unzipped successfully!
# 26 books_es/11657.zip unzipped successfully!
# 28 books_es/11663.zip unzipped successfully!
# 30 books_es/11669.zip unzipped successfully!
# 32 books_es/12274.zip unzipped successfully!
# 33 books_es/12275.zip unzipped successfully!
# 34 books_es/12276.zip unzipped successfully!
# 35 books_es/12501.zip unzipped successfully!
# 36 books_es/12502.zip unzipped successfully!
# 37 books_es/12503.zip unzipped successfully!
# 38 books_es/12368.zip unzipped successfully!
# 40 books_es/12435.zip unzipped successfully!
# 42 books_es/12457.zip unzipped successfully!
# 44 books_es/12627.zip unzipped successfully!
# 46 books_es/12840.zip unzipped successfully!
# 48 books_es/12848.zip unzipped successfully!
# 49 books_es/13210.zip unzipped successfully!
# 51 books_es/13216.zip unzipped successfully!
# 53 books_es/13264.zip unzipped successfully!
# 55 books_es/13458.zip unzipped successfully!
# 56 books_es/13479.zip unzipped successfully!
# 58 books_es/13492.zip unzipped successfully!
# 60 books_es/13507.zip unzipped successfully!
# 62 books_es/13516.zip unzipped successfully!
# 64 books_es/13519.zip unzipped successfully!
# 66 books_es/13608.zip unzipped successfully!
# 68 books_es/13904.zip unzipped successfully!
# 69 books_es/14235.zip unzipped successfully!
# 70 books_es/14236.zip unzipped successfully!
# 71 books_es/14307.zip unzipped successfully!
# 72 books_es/14308.zip unzipped successfully!
# 73 books_es/14311.zip unzipped successfully!
# 74 books_es/14318.zip unzipped successfully!
# 75 books_es/14329.zip unzipped successfully!
# 76 books_es/14722.zip unzipped successfully!
# 77 books_es/14765.zip unzipped successfully!
# 78 books_es/14795.zip unzipped successfully!
# 79 books_es/14796.zip unzipped successfully!
# 80 books_es/14839.zip unzipped successfully!
# 81 books_es/14944.zip unzipped successfully!
# 82 books_es/14995.zip unzipped successfully!
# 83 books_es/15027.zip unzipped successfully!
# 84 books_es/15046.zip unzipped successfully!
# 85 books_es/15054.zip unzipped successfully!
# 86 books_es/15066.zip unzipped successfully!
# 87 books_es/15115.zip unzipped successfully!
# 88 books_es/15127.zip unzipped successfully!
# 90 books_es/15206.zip unzipped successfully!
# 91 books_es/15334.zip unzipped successfully!
# 92 books_es/15353.zip unzipped successfully!
# 94 books_es/15421.zip unzipped successfully!
# 95 books_es/15531.zip unzipped successfully!
# 96 books_es/15532.zip unzipped successfully!
# 98 books_es/15633.zip unzipped successfully!
# 99 books_es/15725.zip unzipped successfully!
# 101 books_es/15757.zip unzipped successfully!
# 102 books_es/15781.zip unzipped successfully!
# 103 books_es/16059.zip unzipped successfully!
# 105 books_es/16082.zip unzipped successfully!
# 106 books_es/16105.zip unzipped successfully!
# 107 books_es/16109.zip unzipped successfully!
# 108 books_es/16110.zip unzipped successfully!
# 109 books_es/16119.zip unzipped successfully!
# 111 books_es/16132.zip unzipped successfully!
# 112 books_es/16149.zip unzipped successfully!
# 113 books_es/16201.zip unzipped successfully!
# 114 books_es/16319.zip unzipped successfully!
# 115 books_es/16372.zip unzipped successfully!
# 116 books_es/16413.zip unzipped successfully!
# 117 books_es/16484.zip unzipped successfully!
# 118 books_es/16625.zip unzipped successfully!
# 119 books_es/16670.zip unzipped successfully!
# 120 books_es/16961.zip unzipped successfully!
# 121 books_es/17013.zip unzipped successfully!
# 122 books_es/17073.zip unzipped successfully!
# 123 books_es/17223.zip unzipped successfully!
# 124 books_es/17317.zip unzipped successfully!
# 125 books_es/17338.zip unzipped successfully!
# 126 books_es/17340.zip unzipped successfully!
# 127 books_es/17341.zip unzipped successfully!
# 128 books_es/17406.zip unzipped successfully!
# 129 books_es/17430.zip unzipped successfully!
# 130 books_es/17443.zip unzipped successfully!
# 131 books_es/17491.zip unzipped successfully!
# 132 books_es/17974.zip unzipped successfully!
# 133 books_es/18005.zip unzipped successfully!
# 134 books_es/18157.zip unzipped successfully!
# 135 books_es/18166.zip unzipped successfully!
# 136 books_es/18228.zip unzipped successfully!
# 137 books_es/18289.zip unzipped successfully!
# 138 books_es/18580.zip unzipped successfully!
# 139 books_es/18600.zip unzipped successfully!
# 140 books_es/18723.zip unzipped successfully!
# 141 books_es/18783.zip unzipped successfully!
# 142 books_es/18784.zip unzipped successfully!
# 143 books_es/18798.zip unzipped successfully!
# 144 books_es/19106.zip unzipped successfully!
# 145 books_es/19496.zip unzipped successfully!
# 146 books_es/19543.zip unzipped successfully!
# 147 books_es/19643.zip unzipped successfully!
# 148 books_es/19847.zip unzipped successfully!
# 149 books_es/19898.zip unzipped successfully!
# 150 books_es/20011.zip unzipped successfully!
# 151 books_es/20099.zip unzipped successfully!
# 152 books_es/20159.zip unzipped successfully!
# 155 books_es/20401.zip unzipped successfully!
# 156 books_es/20738.zip unzipped successfully!
# 157 books_es/20852.zip unzipped successfully!
# 158 books_es/20855.zip unzipped successfully!
# 159 books_es/20930.zip unzipped successfully!
# 160 books_es/21282.zip unzipped successfully!
# 161 books_es/21651.zip unzipped successfully!
# 162 books_es/21831.zip unzipped successfully!
# 163 books_es/21906.zip unzipped successfully!
# 164 books_es/22065.zip unzipped successfully!
# 165 books_es/22092.zip unzipped successfully!
# 166 books_es/22899.zip unzipped successfully!
# 167 books_es/22909.zip unzipped successfully!
# 168 books_es/22975.zip unzipped successfully!
# 169 books_es/23035.zip unzipped successfully!
# 170 books_es/23206.zip unzipped successfully!
# 171 books_es/23236.zip unzipped successfully!
# 172 books_es/23239.zip unzipped successfully!
# 173 books_es/23600.zip unzipped successfully!
# 174 books_es/23617.zip unzipped successfully!
# 175 books_es/23957.zip unzipped successfully!
# 176 books_es/24031.zip unzipped successfully!
# 177 books_es/24127.zip unzipped successfully!
# 178 books_es/24208.zip unzipped successfully!
# 179 books_es/24250.zip unzipped successfully!
# 180 books_es/24466.zip unzipped successfully!
# 181 books_es/24536.zip unzipped successfully!
# 182 books_es/24801.zip unzipped successfully!
# 183 books_es/24802.zip unzipped successfully!
# 184 books_es/24823.zip unzipped successfully!
# 185 books_es/24917.zip unzipped successfully!
# 186 books_es/24925.zip unzipped successfully!
# 187 books_es/24988.zip unzipped successfully!
# 188 books_es/25054.zip unzipped successfully!
# 189 books_es/25074.zip unzipped successfully!
# 190 books_es/25255.zip unzipped successfully!
# 191 books_es/25317.zip unzipped successfully!
# 192 books_es/25320.zip unzipped successfully!
# 193 books_es/25640.zip unzipped successfully!
# 194 books_es/25671.zip unzipped successfully!
# 195 books_es/25687.zip unzipped successfully!
# 196 books_es/25705.zip unzipped successfully!
# 197 books_es/25777.zip unzipped successfully!
# 198 books_es/25807.zip unzipped successfully!
# 199 books_es/25812.zip unzipped successfully!
# 200 books_es/25956.zip unzipped successfully!
# 201 books_es/25988.zip unzipped successfully!
# 202 books_es/26028.zip unzipped successfully!
# 203 books_es/26078.zip unzipped successfully!
# 204 books_es/26231.zip unzipped successfully!
# 205 books_es/26284.zip unzipped successfully!
# 206 books_es/26314.zip unzipped successfully!
# 207 books_es/26404.zip unzipped successfully!
# 208 books_es/26506.zip unzipped successfully!
# 209 books_es/26508.zip unzipped successfully!
# 210 books_es/26545.zip unzipped successfully!
# 211 books_es/26655.zip unzipped successfully!
# 212 books_es/26756.zip unzipped successfully!
# 213 books_es/26771.zip unzipped successfully!
# 214 books_es/26845.zip unzipped successfully!
# 215 books_es/26929.zip unzipped successfully!
# 216 books_es/26947.zip unzipped successfully!
# 217 books_es/27034.zip unzipped successfully!
# 219 books_es/27035.zip unzipped successfully!
# 221 books_es/27048.zip unzipped successfully!
# 223 books_es/26983.zip unzipped successfully!
# 224 books_es/27064.zip unzipped successfully!
# 225 books_es/27100.zip unzipped successfully!
# 226 books_es/27121.zip unzipped successfully!
# 227 books_es/27167.zip unzipped successfully!
# 228 books_es/27214.zip unzipped successfully!
# 229 books_es/27295.zip unzipped successfully!
# 230 books_es/27326.zip unzipped successfully!
# 231 books_es/27695.zip unzipped successfully!
# 232 books_es/27736.zip unzipped successfully!
# 233 books_es/27738.zip unzipped successfully!
# 234 books_es/27757.zip unzipped successfully!
# 235 books_es/27900.zip unzipped successfully!
# 236 books_es/28002.zip unzipped successfully!
# 237 books_es/28106.zip unzipped successfully!
# 238 books_es/28212.zip unzipped successfully!
# 239 books_es/28281.zip unzipped successfully!
# 240 books_es/28408.zip unzipped successfully!
# 241 books_es/28430.zip unzipped successfully!
# 242 books_es/28542.zip unzipped successfully!
# 243 books_es/28592.zip unzipped successfully!
# 244 books_es/28904.zip unzipped successfully!
# 245 books_es/28927.zip unzipped successfully!
# 246 books_es/28929.zip unzipped successfully!
# 247 books_es/28967.zip unzipped successfully!
# 248 books_es/28978.zip unzipped successfully!
# 249 books_es/29014.zip unzipped successfully!
# 250 books_es/29061.zip unzipped successfully!
# 251 books_es/29078.zip unzipped successfully!
# 252 books_es/29105.zip unzipped successfully!
# 253 books_es/29137.zip unzipped successfully!
# 254 books_es/29301.zip unzipped successfully!
# 255 books_es/29497.zip unzipped successfully!
# 256 books_es/29506.zip unzipped successfully!
# 257 books_es/29511.zip unzipped successfully!
# 258 books_es/29576.zip unzipped successfully!
# 259 books_es/29610.zip unzipped successfully!
# 260 books_es/29640.zip unzipped successfully!
# 261 books_es/29663.zip unzipped successfully!
# 262 books_es/29677.zip unzipped successfully!
# 263 books_es/29703.zip unzipped successfully!
# 264 books_es/29706.zip unzipped successfully!
# 265 books_es/29731.zip unzipped successfully!
# 266 books_es/29770.zip unzipped successfully!
# 267 books_es/29799.zip unzipped successfully!
# 268 books_es/29803.zip unzipped successfully!
# 270 books_es/29830.zip unzipped successfully!
# 271 books_es/29831.zip unzipped successfully!
# 272 books_es/29901.zip unzipped successfully!
# 273 books_es/29920.zip unzipped successfully!
# 274 books_es/30052.zip unzipped successfully!
# 275 books_es/30122.zip unzipped successfully!
# 276 books_es/30213.zip unzipped successfully!
# 277 books_es/30275.zip unzipped successfully!
# 278 books_es/30280.zip unzipped successfully!
# 279 books_es/30425.zip unzipped successfully!
# 280 books_es/30535.zip unzipped successfully!
# 281 books_es/30716.zip unzipped successfully!
# 283 books_es/30892.zip unzipped successfully!
# 284 books_es/30903.zip unzipped successfully!
# 285 books_es/30986.zip unzipped successfully!
# 286 books_es/31013.zip unzipped successfully!
# 287 books_es/31066.zip unzipped successfully!
# 288 books_es/31464.zip unzipped successfully!
# 289 books_es/31465.zip unzipped successfully!
# 290 books_es/31541.zip unzipped successfully!
# 291 books_es/31544.zip unzipped successfully!
# 292 books_es/31613.zip unzipped successfully!
# 294 books_es/31633.zip unzipped successfully!
# 296 books_es/31637.zip unzipped successfully!
# 298 books_es/31707.zip unzipped successfully!
# 299 books_es/31724.zip unzipped successfully!
# 300 books_es/32235.zip unzipped successfully!
# 301 books_es/32315.zip unzipped successfully!
# 302 books_es/32364.zip unzipped successfully!
# 303 books_es/33227.zip unzipped successfully!
# 305 books_es/33267.zip unzipped successfully!
# 306 books_es/33275.zip unzipped successfully!
# 307 books_es/33406.zip unzipped successfully!
# 308 books_es/33461.zip unzipped successfully!
# 309 books_es/33474.zip unzipped successfully!
# 310 books_es/33690.zip unzipped successfully!
# 312 books_es/33809.zip unzipped successfully!
# 314 books_es/34091.zip unzipped successfully!
# 315 books_es/33885.zip unzipped successfully!
# 316 books_es/34565.zip unzipped successfully!
# 317 books_es/34731.zip unzipped successfully!
# 320 books_es/35407.zip unzipped successfully!
# 321 books_es/35882.zip unzipped successfully!
# 323 books_es/35905.zip unzipped successfully!
# 324 books_es/36253.zip unzipped successfully!
# 326 books_es/36318.zip unzipped successfully!
# 327 books_es/36453.zip unzipped successfully!
# 328 books_es/36546.zip unzipped successfully!
# 329 books_es/36558.zip unzipped successfully!
# 330 books_es/36573.zip unzipped successfully!
# 331 books_es/36805.zip unzipped successfully!
# 332 books_es/36940.zip unzipped successfully!
# 334 books_es/36986.zip unzipped successfully!
# 336 books_es/36990.zip unzipped successfully!
# 337 books_es/37067.zip unzipped successfully!
# 339 books_es/37095.zip unzipped successfully!
# 341 books_es/37139.zip unzipped successfully!
# 342 books_es/37382.zip unzipped successfully!
# 343 books_es/37590.zip unzipped successfully!
# 344 books_es/37637.zip unzipped successfully!
# 345 books_es/37747.zip unzipped successfully!
# 346 books_es/9890.zip unzipped successfully!
# 347 books_es/9895.zip unzipped successfully!
# 348 books_es/38124.zip unzipped successfully!
# 349 books_es/9980.zip unzipped successfully!
# 350 books_es/6528.zip unzipped successfully!
# 351 books_es/38814.zip unzipped successfully!
# 352 books_es/38836.zip unzipped successfully!
# 353 books_es/38885.zip unzipped successfully!
# 354 books_es/39113.zip unzipped successfully!
# 355 books_es/320.zip unzipped successfully!
# 356 books_es/39209.zip unzipped successfully!
# 357 books_es/39312.zip unzipped successfully!
# 358 books_es/39444.zip unzipped successfully!
# 359 books_es/39446.zip unzipped successfully!
# 360 books_es/39579.zip unzipped successfully!
# 361 books_es/39613.zip unzipped successfully!
# 362 books_es/39647.zip unzipped successfully!
# 363 books_es/5985.zip unzipped successfully!
# 364 books_es/39930.zip unzipped successfully!
# 365 books_es/39947.zip unzipped successfully!
# 366 books_es/39948.zip unzipped successfully!
# 367 books_es/39990.zip unzipped successfully!
# 368 books_es/40066.zip unzipped successfully!
# 369 books_es/40182.zip unzipped successfully!
# 370 books_es/40358.zip unzipped successfully!
# 371 books_es/40420.zip unzipped successfully!
# 373 books_es/40544.zip unzipped successfully!
# 374 books_es/5201.zip unzipped successfully!
# 375 books_es/40595.zip unzipped successfully!
# 376 books_es/40724.zip unzipped successfully!
# 377 books_es/40810.zip unzipped successfully!
# 378 books_es/40827.zip unzipped successfully!
# 379 books_es/41106.zip unzipped successfully!
# 380 books_es/41161.zip unzipped successfully!
# 381 books_es/5877.zip unzipped successfully!
# 382 books_es/5878.zip unzipped successfully!
# 383 books_es/5879.zip unzipped successfully!
# 384 books_es/5880.zip unzipped successfully!
# 385 books_es/5881.zip unzipped successfully!
# 386 books_es/41337.zip unzipped successfully!
# 387 books_es/41575.zip unzipped successfully!
# 388 books_es/41746.zip unzipped successfully!
# 389 books_es/41789.zip unzipped successfully!
# 390 books_es/41842.zip unzipped successfully!
# 391 books_es/41853.zip unzipped successfully!
# 392 books_es/41884.zip unzipped successfully!
# 393 books_es/42023.zip unzipped successfully!
# 394 books_es/42065.zip unzipped successfully!
# 395 books_es/42321.zip unzipped successfully!
# 396 books_es/42323.zip unzipped successfully!
# 397 books_es/42376.zip unzipped successfully!
# 398 books_es/42424.zip unzipped successfully!
# 399 books_es/42440.zip unzipped successfully!
# 400 books_es/42456.zip unzipped successfully!
# 401 books_es/42642.zip unzipped successfully!
# 402 books_es/42705.zip unzipped successfully!
# 403 books_es/42727.zip unzipped successfully!
# 404 books_es/43017.zip unzipped successfully!
# 405 books_es/43030.zip unzipped successfully!
# 406 books_es/43033.zip unzipped successfully!
# 407 books_es/43276.zip unzipped successfully!
# 408 books_es/43400.zip unzipped successfully!
# 409 books_es/43401.zip unzipped successfully!
# 410 books_es/43432.zip unzipped successfully!
# 411 books_es/43493.zip unzipped successfully!
# 412 books_es/43861.zip unzipped successfully!
# 413 books_es/43950.zip unzipped successfully!
# 414 books_es/44112.zip unzipped successfully!
# 415 books_es/44120.zip unzipped successfully!
# 416 books_es/44173.zip unzipped successfully!
# 417 books_es/44305.zip unzipped successfully!
# 418 books_es/44309.zip unzipped successfully!
# 419 books_es/44358.zip unzipped successfully!
# 420 books_es/44512.zip unzipped successfully!
# 421 books_es/44529.zip unzipped successfully!
# 422 books_es/44584.zip unzipped successfully!
# 423 books_es/44918.zip unzipped successfully!
# 424 books_es/45151.zip unzipped successfully!
# 425 books_es/45171.zip unzipped successfully!
# 426 books_es/45180.zip unzipped successfully!
# 427 books_es/45183.zip unzipped successfully!
# 428 books_es/45250.zip unzipped successfully!
# 429 books_es/45438.zip unzipped successfully!
# 430 books_es/45508.zip unzipped successfully!
# 431 books_es/45770.zip unzipped successfully!
# 432 books_es/45829.zip unzipped successfully!
# 433 books_es/45830.zip unzipped successfully!
# 434 books_es/45831.zip unzipped successfully!
# 435 books_es/45832.zip unzipped successfully!
# 436 books_es/45833.zip unzipped successfully!
# 437 books_es/45834.zip unzipped successfully!
# 438 books_es/45835.zip unzipped successfully!
# 439 books_es/45836.zip unzipped successfully!
# 440 books_es/45837.zip unzipped successfully!
# 441 books_es/45945.zip unzipped successfully!
# 442 books_es/46000.zip unzipped successfully!
# 443 books_es/46182.zip unzipped successfully!
# 444 books_es/46196.zip unzipped successfully!
# 445 books_es/46201.zip unzipped successfully!
# 446 books_es/46246.zip unzipped successfully!
# 448 books_es/46265.zip unzipped successfully!
# 449 books_es/46279.zip unzipped successfully!
# 450 books_es/46496.zip unzipped successfully!
# 451 books_es/46771.zip unzipped successfully!
# 452 books_es/7109.zip unzipped successfully!
# 453 books_es/8870.zip unzipped successfully!
# 454 books_es/47052.zip unzipped successfully!
# 455 books_es/47057.zip unzipped successfully!
# 456 books_es/47092.zip unzipped successfully!
# 457 books_es/47103.zip unzipped successfully!
# 458 books_es/47184.zip unzipped successfully!
# 459 books_es/47287.zip unzipped successfully!
# 460 books_es/47346.zip unzipped successfully!
# 461 books_es/47388.zip unzipped successfully!
# 462 books_es/47572.zip unzipped successfully!
# 463 books_es/47584.zip unzipped successfully!
# 464 books_es/47631.zip unzipped successfully!
# 465 books_es/47650.zip unzipped successfully!
# 466 books_es/47768.zip unzipped successfully!
# 467 books_es/47784.zip unzipped successfully!
# 468 books_es/48081.zip unzipped successfully!
# 469 books_es/48091.zip unzipped successfully!
# 470 books_es/48092.zip unzipped successfully!
# 471 books_es/48093.zip unzipped successfully!
# 472 books_es/48302.zip unzipped successfully!
# 473 books_es/48651.zip unzipped successfully!
# 474 books_es/48652.zip unzipped successfully!
# 475 books_es/48654.zip unzipped successfully!
# 476 books_es/48670.zip unzipped successfully!
# 477 books_es/1619.zip unzipped successfully!
# 478 books_es/48783.zip unzipped successfully!
# 479 books_es/48857.zip unzipped successfully!
# 480 books_es/48903.zip unzipped successfully!
# 481 books_es/48940.zip unzipped successfully!
# 482 books_es/48944.zip unzipped successfully!
# 483 books_es/48945.zip unzipped successfully!
# 484 books_es/48946.zip unzipped successfully!
# 485 books_es/48954.zip unzipped successfully!
# 486 books_es/49013.zip unzipped successfully!
# 487 books_es/49063.zip unzipped successfully!
# 488 books_es/49149.zip unzipped successfully!
# 489 books_es/49258.zip unzipped successfully!
# 490 books_es/49259.zip unzipped successfully!
# 491 books_es/49280.zip unzipped successfully!
# 492 books_es/49298.zip unzipped successfully!
# 493 books_es/49333.zip unzipped successfully!
# 494 books_es/49354.zip unzipped successfully!
# 495 books_es/49359.zip unzipped successfully!
# 496 books_es/49376.zip unzipped successfully!
# 497 books_es/49388.zip unzipped successfully!
# 498 books_es/49413.zip unzipped successfully!
# 499 books_es/49417.zip unzipped successfully!
# 500 books_es/49418.zip unzipped successfully!
# 501 books_es/49433.zip unzipped successfully!
# 502 books_es/49437.zip unzipped successfully!
# 503 books_es/49470.zip unzipped successfully!
# 504 books_es/49560.zip unzipped successfully!
# 505 books_es/49660.zip unzipped successfully!
# 506 books_es/49756.zip unzipped successfully!
# 507 books_es/49836.zip unzipped successfully!
# 508 books_es/49914.zip unzipped successfully!
# 509 books_es/50027.zip unzipped successfully!
# 510 books_es/50126.zip unzipped successfully!
# 511 books_es/50291.zip unzipped successfully!
# 512 books_es/50341.zip unzipped successfully!
# 513 books_es/50351.zip unzipped successfully!
# 514 books_es/50365.zip unzipped successfully!
# 515 books_es/50430.zip unzipped successfully!
# 516 books_es/50437.zip unzipped successfully!
# 517 books_es/50492.zip unzipped successfully!
# 518 books_es/50526.zip unzipped successfully!
# 519 books_es/50726.zip unzipped successfully!
# 520 books_es/50757.zip unzipped successfully!
# 521 books_es/51019.zip unzipped successfully!
# 522 books_es/51020.zip unzipped successfully!
# 523 books_es/51029.zip unzipped successfully!
# 524 books_es/51130.zip unzipped successfully!
# 525 books_es/51450.zip unzipped successfully!
# 526 books_es/51458.zip unzipped successfully!
# 527 books_es/51465.zip unzipped successfully!
# 528 books_es/51569.zip unzipped successfully!
# 529 books_es/51604.zip unzipped successfully!
# 530 books_es/51627.zip unzipped successfully!
# 531 books_es/51689.zip unzipped successfully!
# 532 books_es/51711.zip unzipped successfully!
# 533 books_es/51721.zip unzipped successfully!
# 534 books_es/51724.zip unzipped successfully!
# 535 books_es/51858.zip unzipped successfully!
# 536 books_es/51870.zip unzipped successfully!
# 537 books_es/52036.zip unzipped successfully!
# 538 books_es/52050.zip unzipped successfully!
# 539 books_es/52093.zip unzipped successfully!
# 540 books_es/52262.zip unzipped successfully!
# 541 books_es/52392.zip unzipped successfully!
# 542 books_es/52469.zip unzipped successfully!
# 543 books_es/52499.zip unzipped successfully!
# 544 books_es/52502.zip unzipped successfully!
# 545 books_es/52595.zip unzipped successfully!
# 546 books_es/52597.zip unzipped successfully!
# 547 books_es/52682.zip unzipped successfully!
# 548 books_es/52795.zip unzipped successfully!
# 549 books_es/52837.zip unzipped successfully!
# 550 books_es/52857.zip unzipped successfully!
# 551 books_es/52894.zip unzipped successfully!
# 552 books_es/53003.zip unzipped successfully!
# 553 books_es/53131.zip unzipped successfully!
# 554 books_es/53171.zip unzipped successfully!
# 555 books_es/53185.zip unzipped successfully!
# 556 books_es/53207.zip unzipped successfully!
# 557 books_es/53294.zip unzipped successfully!
# 558 books_es/53330.zip unzipped successfully!
# 559 books_es/53355.zip unzipped successfully!
# 560 books_es/53405.zip unzipped successfully!
# 561 books_es/53413.zip unzipped successfully!
# 562 books_es/53421.zip unzipped successfully!
# 563 books_es/53429.zip unzipped successfully!
# 564 books_es/53436.zip unzipped successfully!
# 565 books_es/53462.zip unzipped successfully!
# 566 books_es/53517.zip unzipped successfully!
# 567 books_es/53552.zip unzipped successfully!
# 568 books_es/53590.zip unzipped successfully!
# 569 books_es/53587.zip unzipped successfully!
# 570 books_es/53588.zip unzipped successfully!
# 571 books_es/53589.zip unzipped successfully!
# 572 books_es/53718.zip unzipped successfully!
# 573 books_es/53741.zip unzipped successfully!
# 574 books_es/53742.zip unzipped successfully!
# 575 books_es/53743.zip unzipped successfully!
# 576 books_es/53798.zip unzipped successfully!
# 577 books_es/53837.zip unzipped successfully!
# 578 books_es/53867.zip unzipped successfully!
# 579 books_es/53927.zip unzipped successfully!
# 580 books_es/53930.zip unzipped successfully!
# 581 books_es/53947.zip unzipped successfully!
# 582 books_es/54064.zip unzipped successfully!
# 583 books_es/54112.zip unzipped successfully!
# 584 books_es/54120.zip unzipped successfully!
# 585 books_es/54228.zip unzipped successfully!
# 586 books_es/54282.zip unzipped successfully!
# 587 books_es/54283.zip unzipped successfully!
# 588 books_es/54285.zip unzipped successfully!
# 589 books_es/54386.zip unzipped successfully!
# 590 books_es/54423.zip unzipped successfully!
# 591 books_es/54430.zip unzipped successfully!
# 592 books_es/54436.zip unzipped successfully!
# 593 books_es/54471.zip unzipped successfully!
# 594 books_es/54522.zip unzipped successfully!
# 595 books_es/54521.zip unzipped successfully!
# 596 books_es/54791.zip unzipped successfully!
# 597 books_es/54861.zip unzipped successfully!
# 598 books_es/54934.zip unzipped successfully!
# 599 books_es/55038.zip unzipped successfully!
# 600 books_es/55058.zip unzipped successfully!
# 601 books_es/55139.zip unzipped successfully!
# 602 books_es/55157.zip unzipped successfully!
# 603 books_es/55206.zip unzipped successfully!
# 604 books_es/55215.zip unzipped successfully!
# 605 books_es/55440.zip unzipped successfully!
# 606 books_es/55448.zip unzipped successfully!
# 607 books_es/55480.zip unzipped successfully!
# 608 books_es/55514.zip unzipped successfully!
# 609 books_es/55563.zip unzipped successfully!
# 610 books_es/55616.zip unzipped successfully!
# 611 books_es/55796.zip unzipped successfully!
# 612 books_es/55812.zip unzipped successfully!
# 613 books_es/55882.zip unzipped successfully!
# 614 books_es/55915.zip unzipped successfully!
# 615 books_es/55916.zip unzipped successfully!
# 616 books_es/55917.zip unzipped successfully!
# 617 books_es/56010.zip unzipped successfully!
# 618 books_es/56044.zip unzipped successfully!
# 619 books_es/56047.zip unzipped successfully!
# 620 books_es/56051.zip unzipped successfully!
# 621 books_es/56219.zip unzipped successfully!
# 622 books_es/56251.zip unzipped successfully!
# 623 books_es/56283.zip unzipped successfully!
# 624 books_es/56301.zip unzipped successfully!
# 625 books_es/56451.zip unzipped successfully!
# 626 books_es/56452.zip unzipped successfully!
# 627 books_es/56454.zip unzipped successfully!
# 628 books_es/56519.zip unzipped successfully!
# 629 books_es/56624.zip unzipped successfully!
# 630 books_es/56770.zip unzipped successfully!
# 631 books_es/57035.zip unzipped successfully!
# 632 books_es/57225.zip unzipped successfully!
# 633 books_es/57261.zip unzipped successfully!
# 634 books_es/57263.zip unzipped successfully!
# 635 books_es/57264.zip unzipped successfully!
# 636 books_es/57303.zip unzipped successfully!
# 637 books_es/57388.zip unzipped successfully!
# 638 books_es/57448.zip unzipped successfully!
# 639 books_es/57505.zip unzipped successfully!
# 640 books_es/57550.zip unzipped successfully!
# 641 books_es/57590.zip unzipped successfully!
# 642 books_es/57648.zip unzipped successfully!
# 643 books_es/57654.zip unzipped successfully!
# 644 books_es/57675.zip unzipped successfully!
# 645 books_es/57781.zip unzipped successfully!
# 646 books_es/57828.zip unzipped successfully!
# 647 books_es/57955.zip unzipped successfully!
# 648 books_es/57960.zip unzipped successfully!
# 649 books_es/57982.zip unzipped successfully!
# 650 books_es/58049.zip unzipped successfully!
# 651 books_es/58059.zip unzipped successfully!
# 652 books_es/58077.zip unzipped successfully!
# 653 books_es/58103.zip unzipped successfully!
# 654 books_es/58194.zip unzipped successfully!
# 655 books_es/58221.zip unzipped successfully!
# 656 books_es/58261.zip unzipped successfully!
# 657 books_es/58275.zip unzipped successfully!
# 658 books_es/58298.zip unzipped successfully!
# 659 books_es/58331.zip unzipped successfully!
# 660 books_es/58375.zip unzipped successfully!
# 661 books_es/58425.zip unzipped successfully!
# 662 books_es/58484.zip unzipped successfully!
# 663 books_es/58545.zip unzipped successfully!
# 664 books_es/58643.zip unzipped successfully!
# 665 books_es/58713.zip unzipped successfully!
# 666 books_es/58865.zip unzipped successfully!
# 667 books_es/58910.zip unzipped successfully!
# 668 books_es/58916.zip unzipped successfully!
# 669 books_es/59154.zip unzipped successfully!
# 670 books_es/59189.zip unzipped successfully!
# 671 books_es/59244.zip unzipped successfully!
# 672 books_es/59492.zip unzipped successfully!
# 673 books_es/59539.zip unzipped successfully!
# 674 books_es/59564.zip unzipped successfully!
# 675 books_es/59629.zip unzipped successfully!
# 676 books_es/59631.zip unzipped successfully!
# 677 books_es/59686.zip unzipped successfully!
# 678 books_es/59797.zip unzipped successfully!
# 679 books_es/59852.zip unzipped successfully!
# 680 books_es/59879.zip unzipped successfully!
# 681 books_es/59925.zip unzipped successfully!
# 682 books_es/60117.zip unzipped successfully!
# 683 books_es/60137.zip unzipped successfully!
# 684 books_es/60147.zip unzipped successfully!
# 685 books_es/60198.zip unzipped successfully!
# 686 books_es/60210.zip unzipped successfully!
# 687 books_es/60284.zip unzipped successfully!
# 688 books_es/60376.zip unzipped successfully!
# 689 books_es/60464.zip unzipped successfully!
# 690 books_es/60510.zip unzipped successfully!
# 691 books_es/60634.zip unzipped successfully!
# 692 books_es/60675.zip unzipped successfully!
# 693 books_es/60748.zip unzipped successfully!
# 694 books_es/60884.zip unzipped successfully!
# 695 books_es/60927.zip unzipped successfully!
# 696 books_es/60971.zip unzipped successfully!
# 697 books_es/61022.zip unzipped successfully!
# 698 books_es/61189.zip unzipped successfully!
# 699 books_es/61202.zip unzipped successfully!
# 700 books_es/61244.zip unzipped successfully!
# 701 books_es/61339.zip unzipped successfully!
# 702 books_es/61361.zip unzipped successfully!
# 703 books_es/61438.zip unzipped successfully!
# 704 books_es/61465.zip unzipped successfully!
# 705 books_es/61508.zip unzipped successfully!
# 706 books_es/61573.zip unzipped successfully!
# 707 books_es/61594.zip unzipped successfully!
# 708 books_es/61700.zip unzipped successfully!
# 709 books_es/61739.zip unzipped successfully!
# 710 books_es/61831.zip unzipped successfully!
# 711 books_es/61832.zip unzipped successfully!
# 712 books_es/61851.zip unzipped successfully!
# 713 books_es/61874.zip unzipped successfully!
# 714 books_es/61887.zip unzipped successfully!
# 715 books_es/61917.zip unzipped successfully!
# 716 books_es/62019.zip unzipped successfully!
# 717 books_es/62201.zip unzipped successfully!
# 718 books_es/62211.zip unzipped successfully!
# 719 books_es/62356.zip unzipped successfully!
# 720 books_es/62359.zip unzipped successfully!
# 721 books_es/62450.zip unzipped successfully!
# 722 books_es/62475.zip unzipped successfully!
# 723 books_es/62559.zip unzipped successfully!
# 724 books_es/62564.zip unzipped successfully!
# 725 books_es/62361.zip unzipped successfully!
# 726 books_es/62627.zip unzipped successfully!
# 727 books_es/62691.zip unzipped successfully!
# 728 books_es/62711.zip unzipped successfully!
# 729 books_es/62785.zip unzipped successfully!
# 730 books_es/62840.zip unzipped successfully!
# 731 books_es/62850.zip unzipped successfully!
# 732 books_es/62870.zip unzipped successfully!
# 733 books_es/62926.zip unzipped successfully!
# 734 books_es/62952.zip unzipped successfully!
# 735 books_es/62984.zip unzipped successfully!
# 736 books_es/62986.zip unzipped successfully!
# 737 books_es/63019.zip unzipped successfully!
# 738 books_es/63030.zip unzipped successfully!
# 740 books_es/63061.zip unzipped successfully!
# 743 books_es/63101.zip unzipped successfully!
# 745 books_es/63228.zip unzipped successfully!
# 746 books_es/63328.zip unzipped successfully!
# 747 books_es/63359.zip unzipped successfully!
# 748 books_es/63378.zip unzipped successfully!
# 749 books_es/63402.zip unzipped successfully!
# 750 books_es/63412.zip unzipped successfully!
# 751 books_es/63413.zip unzipped successfully!
# 752 books_es/63414.zip unzipped successfully!
# 753 books_es/63424.zip unzipped successfully!
# 754 books_es/63464.zip unzipped successfully!
# 755 books_es/63509.zip unzipped successfully!
# 756 books_es/63525.zip unzipped successfully!
# 757 books_es/63587.zip unzipped successfully!
# 758 books_es/63600.zip unzipped successfully!
# 759 books_es/63680.zip unzipped successfully!
# 760 books_es/63700.zip unzipped successfully!
# 761 books_es/63767.zip unzipped successfully!
# 762 books_es/63810.zip unzipped successfully!
# 763 books_es/63816.zip unzipped successfully!
# 764 books_es/63823.zip unzipped successfully!
# 765 books_es/63922.zip unzipped successfully!
# 766 books_es/30053.zip unzipped successfully!
# 767 books_es/64058.zip unzipped successfully!
# 768 books_es/64188.zip unzipped successfully!
# 769 books_es/2000.zip unzipped successfully!
# 770 books_es/64418.zip unzipped successfully!
# 771 books_es/64439.zip unzipped successfully!
# 772 books_es/64465.zip unzipped successfully!
# 773 books_es/12500.zip unzipped successfully!
# 774 books_es/64589.zip unzipped successfully!
# 775 books_es/64656.zip unzipped successfully!
# 776 books_es/64668.zip unzipped successfully!
# 777 books_es/64775.zip unzipped successfully!
# 778 books_es/64945.zip unzipped successfully!
# 779 books_es/64946.zip unzipped successfully!
# 780 books_es/64947.zip unzipped successfully!
# 781 books_es/64974.zip unzipped successfully!
# 782 books_es/65024.zip unzipped successfully!
# 783 books_es/65034.zip unzipped successfully!
# 784 books_es/65158.zip unzipped successfully!
# 785 books_es/65165.zip unzipped successfully!
# 786 books_es/65333.zip unzipped successfully!
# 787 books_es/65410.zip unzipped successfully!
# 788 books_es/65486.zip unzipped successfully!
# 789 books_es/65584.zip unzipped successfully!
# 790 books_es/65632.zip unzipped successfully!
# 791 books_es/65685.zip unzipped successfully!
# 792 books_es/65689.zip unzipped successfully!
# 793 books_es/65719.zip unzipped successfully!
# 794 books_es/65738.zip unzipped successfully!
# 795 books_es/24601.zip unzipped successfully!
# 796 books_es/65815.zip unzipped successfully!
# 797 books_es/65880.zip unzipped successfully!
# 798 books_es/65937.zip unzipped successfully!
# 799 books_es/65988.zip unzipped successfully!
# 800 books_es/65999.zip unzipped successfully!
# 801 books_es/66023.zip unzipped successfully!

# %%
dir_books_es = list(glob.glob("books_es/*.txt"))

# %%
dict_book_es = dict()

num = 0

for book in dir_books_es:
    try:
        with open(book) as f:
            lines = f.read()
    
    except:
        try:
            with open(book, encoding="utf8") as f:
                lines = f.read()
        except:
            try:
                lines = codecs.open(book, 'r', 'ISO-8859-1').read()

        
            except:
                dict_s['length'] = -1
                dict_s['ebook_num'] = book.split("\\")[1].split('.')[0]
                dict_s['ebook_dir'] = book

                dict_s['Title'] = ''
                dict_s['Language'] = ''
                dict_s['encoding'] = ''
                dict_book_es[num] = dict_s
                continue
            
        
        
    info_beg = lines.find('Title: ')
    begin = lines.find('*** START OF THIS PROJECT GUTENBERG EBOOK')
    if begin == -1:
            begin = lines.find('START OF THE PROJECT GUTENBERG EBOOK')
            
    end = lines.find('*** END OF THIS PROJECT GUTENBERG EBOOK')
    if end == -1:
        end = lines.find('*** END')
        
    info = lines[info_beg : begin].split('\n')
    dict_s = dict()
    
    for i in info:
            
        if i.find('Title: ') > -1:
            dict_s['Title'] = i.split('Title: ')[1]
            
        if i.find('Language: ') > -1:
            dict_s['Language'] = i.split('Language: ')[1]
            
        if i.find('Character set encoding: ') > -1:
            dict_s['encoding'] = i.split('Character set encoding: ')[1]
            
    with open(book, 'w', encoding='utf8') as fn:
        fn.write(lines)
               
             
    dict_s['length'] = len(lines[begin : end].split(' '))
    dict_s['ebook_num'] = book.split("\\")[1].split('.')[0]
    dict_s['ebook_dir'] = book
    dict_book_es[num] = dict_s
    num += 1

# %%
books_es = pd.DataFrame(dict_book_es.values())

# %%
books_error = books_es[books_es['length'] < 10]

# %%
books_error.shape
# Out:
# (1, 6)

# %%
books_error
# Out:
#    Title Language encoding  length ebook_num          ebook_dir
# 79   NaN      NaN      NaN       1      1619  books_es\1619.txt

# %%
books_wo_error = books_es[books_es['length'] > 10]
books_wo_error.to_csv('books_list_es.csv')

# %%
books_wo_error.shape
# Out:
# (739, 6)
